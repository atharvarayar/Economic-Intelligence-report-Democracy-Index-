# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr

# %%
df=pd.read_excel('2024 Democracy Index.xlsx')
df.head()
# Out:
#         Entity Code World region according to OWID  Year  Democracy Index  \
# 0  Afghanistan  AFG                           Asia  2006             3.06
# 1  Afghanistan  AFG                           Asia  2008             3.02
# 2  Afghanistan  AFG                           Asia  2010             2.48
# 3  Afghanistan  AFG                           Asia  2011             2.48
# 4  Afghanistan  AFG                           Asia  2012             2.48
#
#    Regime Classification Number Regime Classification  Civil Liberties Index  \
# 0                             0  Authoritarian regime                   4.41
# 1                             0  Authoritarian regime                   4.41
# 2                             0  Authoritarian regime                   3.82
# 3                             0  Authoritarian regime                   3.82
# 4                             0  Authoritarian regime                   3.82
#
#    Democratic Culture Index  Electoral Pluralism Index  \
# 0                       2.5                       6.17
# 1                       2.5                       5.17
# 2                       2.5                       2.50
# 3                       2.5                       2.50
# 4                       2.5                       2.50
#
#    Functioning Government Index  Political Participation Index
# 0                          0.00                           2.22
# 1                          0.79                           2.22
# 2                          0.79                           2.78
# 3                          0.79                           2.78
# 4                          0.79                           2.78

# %%
df.shape
# Out:
# (2839, 12)

# %%
df.describe()
# Out:
#               Year  Democracy Index  Regime Classification Number  \
# count  2839.000000      2839.000000                    2839.00000
# mean   2015.823529         5.437196                       1.26770
# std       5.194070         2.249399                       1.06295
# min    2006.000000         0.250000                       0.00000
# 25%    2012.000000         3.405000                       0.00000
# 50%    2016.000000         5.730000                       1.00000
# 75%    2020.000000         7.240000                       2.00000
# max    2024.000000         9.930000                       3.00000
#
#        Civil Liberties Index  Democratic Culture Index  \
# count            2839.000000               2839.000000
# mean                5.902455                  5.536636
# std                 2.774822                  1.727107
# min                 0.000000                  1.250000
# 25%                 3.530000                  4.380000
# 50%                 6.180000                  5.630000
# 75%                 8.530000                  6.250000
# max                10.000000                 10.000000
#
#        Electoral Pluralism Index  Functioning Government Index  \
# count                2839.000000                   2839.000000
# mean                    5.843815                      4.850391
# std                     3.639116                      2.539509
# min                    -0.330000                      0.000000
# 25%                     2.500000                      2.860000
# 50%                     7.000000                      5.000000
# 75%                     9.170000                      6.790000
# max                    10.000000                     10.000000
#
#        Political Participation Index
# count                    2839.000000
# mean                        5.056365
# std                         1.960076
# min                         0.000000
# 25%                         3.890000
# 50%                         5.000000
# 75%                         6.670000
# max                        10.000000

# %%
df.dtypes
# Out:
# Entity                             object
# Code                               object
# World region according to OWID     object
# Year                                int64
# Democracy Index                   float64
# Regime Classification Number        int64
# Regime Classification              object
# Civil Liberties Index             float64
# Democratic Culture Index          float64
# Electoral Pluralism Index         float64
# Functioning Government Index      float64
# Political Participation Index     float64
# dtype: object

# %%
df['Regime Classification'].unique()
# Out:
# array(['Authoritarian regime', 'Hybrid regime', 'Flawed democracy',
#        'Full democracy'], dtype=object)

# %%
df['Entity'].nunique()
# Out:
# 167

# %% [markdown]
# So we have data of 167 countries in total from year 2006 to 2024.
# Now let's explore what these indices actually mean, used claude for this part as column descriptions were not available in the original dataset-
#
# ### Electoral Pluralism Index —
# Whether elections are free and fair. Covers voter registration, multi-party competition, electoral integrity, and whether opposition parties can actually operate and win. It's the most foundational pillar — you can't be a democracy without it.
#
# ### Civil Liberties Index —
# The freedoms people have in daily life: press freedom, freedom of speech and assembly, protection from arbitrary detention, an independent judiciary, and the rule of law. A country can hold elections but still score poorly here if dissent is suppressed.
#
# ### Functioning Government Index —
# Whether the government actually governs effectively and democratically. Looks at how much elected officials control policy (vs. the military, oligarchs, or foreign powers), government transparency, corruption levels, and citizens' confidence in institutions.
#
# ### Political Participation Index —
# How engaged citizens are beyond just voting. Includes membership in political parties and civil society organizations, interest in politics, and whether women and minorities have meaningful political representation. Low scores here often signal apathy or deliberate exclusion.
#
# ### Democratic Culture Index —
# The most subjective of the five. Measures whether society believes in democracy — do people support it over strong-man rule? Is there tolerance for minority views? Do citizens separate civil from religious authority? This captures whether democratic institutions have genuine public backing or are just a thin facade.

# %%
numeric_df = df.select_dtypes(include=[np.number])

# Remove missing values
numeric_df = numeric_df.dropna()

# ============================================
# PEARSON CORRELATION MATRIX
# ============================================

corr_matrix = numeric_df.corr(method='pearson')

print("\n========== PEARSON CORRELATION MATRIX ==========\n")
print(corr_matrix)

# ============================================
# P-VALUE MATRIX
# ============================================

cols = numeric_df.columns

pval_matrix = pd.DataFrame(
    np.ones((len(cols), len(cols))),
    columns=cols,
    index=cols
)

for i in range(len(cols)):
    for j in range(len(cols)):

        if i == j:
            pval_matrix.iloc[i, j] = 0

        else:
            corr, pval = pearsonr(
                numeric_df.iloc[:, i],
                numeric_df.iloc[:, j]
            )

            pval_matrix.iloc[i, j] = pval

print("\n========== P-VALUE MATRIX ==========\n")
print(pval_matrix)

# ============================================
# DEMOCRACY INDEX RELATIONSHIPS
# ============================================

TARGET_COL = "Democracy Index"   # change if needed

print(f"\n========== VARIABLES RELATED TO {TARGET_COL} ==========\n")

results = []

for col in cols:

    if col == TARGET_COL:
        continue

    corr, pval = pearsonr(
        numeric_df[TARGET_COL],
        numeric_df[col]
    )

    results.append({
        "Variable": col,
        "Correlation": corr,
        "P_Value": pval,
        "Significant": pval < 0.05
    })

results_df = pd.DataFrame(results)

# Sort by absolute correlation strength
results_df["Abs_Corr"] = results_df["Correlation"].abs()

results_df = results_df.sort_values(
    by="Abs_Corr",
    ascending=False
)

print(results_df[
    ["Variable", "Correlation", "P_Value", "Significant"]
])

# ============================================
# OPTIONAL: SPEARMAN TESTS
# ============================================

print("\n========== SPEARMAN CORRELATIONS ==========\n")

spearman_results = []

for col in cols:

    if col == TARGET_COL:
        continue

    corr, pval = spearmanr(
        numeric_df[TARGET_COL],
        numeric_df[col]
    )

    spearman_results.append({
        "Variable": col,
        "Spearman_Corr": corr,
        "P_Value": pval,
        "Significant": pval < 0.05
    })

spearman_df = pd.DataFrame(spearman_results)

spearman_df["Abs_Corr"] = spearman_df["Spearman_Corr"].abs()

spearman_df = spearman_df.sort_values(
    by="Abs_Corr",
    ascending=False
)

print(spearman_df[
    ["Variable", "Spearman_Corr", "P_Value", "Significant"]
])
# Out:
# ========== PEARSON CORRELATION MATRIX ==========
#
#                                    Year  Democracy Index  \
# Year                           1.000000        -0.042551
# Democracy Index               -0.042551         1.000000
# Regime Classification Number               0.000000e+00
# Civil Liberties Index                     5.644170e-283
# Democratic Culture Index                   0.000000e+00
# Electoral Pluralism Index                 3.322290e-188
# Functioning Government Index               0.000000e+00
# Political Participation Index             4.138380e-240
#
#                                Electoral Pluralism Index  \
# Year                                        1.152717e-02
# Democracy Index                             0.000000e+00
# Regime Classification Number                0.000000e+00
# Civil Liberties Index                       0.000000e+00
# Democratic Culture Index                   3.322290e-188
# Electoral Pluralism Index                   0.000000e+00
# Functioning Government Index                0.000000e+00
# Political Participation Index               0.000000e+00
#
#                                Functioning Government Index  \
# Year                                               0.005737
# Democracy Index                                    0.000000
# Regime Classification Number                       0.000000
# Civil Liberties Index                              0.000000
# Democratic Culture Index                           0.000000
# Electoral Pluralism Index                          0.000000
# Functioning Government Index                       0.000000
# Political Participation Index                      0.000000
#
#                                Political Participation Index
# Year                                            5.794435e-16
# Democracy Index                                 0.000000e+00
# Regime Classification Number                    0.000000e+00
# Civil Liberties Index                           0.000000e+00
# Democratic Culture Index                       4.138380e-240
# Electoral Pluralism Index                       0.000000e+00
# Functioning Government Index                    0.000000e+00
# Political Participation Index                   0.000000e+00
#
# ========== VARIABLES RELATED TO Democracy Index ==========
#
#                         Variable  Correlation   P_Value  Significant
# 1   Regime Classification Number     0.954443  0.000000         True
# 2          Civil Liberties Index     0.948185  0.000000         True
# 4      Electoral Pluralism Index     0.935588  0.000000         True
# 5   Functioning Government Index     0.916293  0.000000         True
# 6  Political Participation Index     0.837132  0.000000         True
# 3       Democratic Culture Index     0.719921  0.000000         True
# 0                           Year    -0.042551  0.023377         True
#
# ========== SPEARMAN CORRELATIONS ==========
#
#                         Variable  Spearman_Corr   P_Value  Significant
# 1   Regime Classification Number       0.959399  0.000000         True
# 4      Electoral Pluralism Index       0.953970  0.000000         True
# 2          Civil Liberties Index       0.952265  0.000000         True
# 5   Functioning Government Index       0.923994  0.000000         True
# 6  Political Participation Index       0.830119  0.000000         True
# 3       Democratic Culture Index       0.690343  0.000000         True
# 0                           Year      -0.042497  0.023553         True

# %% [markdown]
# ## year has positive correaltion with political corerlation with political participation, but has negative corelation with Democracy index , meaning over the years the political participation is rising but democracy index is declining

# %%
df['Year'] = df['Year'].astype(int)

# %%
yearly_trends=df.groupby('Year')[['Political Participation Index','Democracy Index']].mean()
print(yearly_trends)
# Out:
#       Political Participation Index  Democracy Index
# Year
# 2006                       4.454850         5.519281
# 2008                       4.591377         5.547665
# 2010                       4.571018         5.462335
# 2011                       4.720659         5.490599
# 2012                       4.840419         5.519401
# 2013                       4.953772         5.534132
# 2014                       5.037006         5.548024
# 2015                       5.103533         5.552994
# 2016                       5.116467         5.520060
# 2017                       5.146407         5.475449
# 2018                       5.249760         5.478563
# 2019                       5.279701         5.439641
# 2020                       5.389401         5.369760
# 2021                       5.392575         5.281377
# 2022                       5.435749         5.293174
# 2023                       5.342695         5.225329
# 2024                       5.332814         5.174551

# %%
yearly_trends.plot(figsize=(10,6))
plt.title("DemocracyIndex vs Political Participation Index")
plt.ylabel("Average Score")
plt.xticks(yearly_trends.index.astype(int))
plt.show()
